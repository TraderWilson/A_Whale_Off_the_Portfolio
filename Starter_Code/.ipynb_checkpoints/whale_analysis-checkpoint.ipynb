# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
import seaborn as sns
from pathlib import Path

# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp500_history.csv`: Contains historical closing prices of the S&P 500 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Reading whale returns
whale_data = Path("../Starter_Code/Resources/whale_returns.csv")
whale_df = pd.read_csv(whale_data, index_col = 'Date', parse_dates = True, infer_datetime_format = True)
whale_df.sort_index(inplace = True)
whale_df.head()
# Out:
# /var/folders/lt/6l09ks9x0bg715j61zl5fbb00000gn/T/ipykernel_2374/3709461225.py:3: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   whale_df = pd.read_csv(whale_data, index_col = 'Date', parse_dates = True, infer_datetime_format = True)
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# ...

# %%
# Count nulls
whale_df.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
whale_df.dropna(inplace = True)
whale_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098
# 2015-03-09                     0.005843               -0.001652

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
# Reading algorithmic returns
algo_data = Path("../Starter_Code/Resources/algo_returns.csv")
algo_df = pd.read_csv(algo_data, index_col = 'Date', parse_dates = True, infer_datetime_format = True)
algo_df.sort_index(inplace = True)
algo_df.head()
# Out:
# /var/folders/lt/6l09ks9x0bg715j61zl5fbb00000gn/T/ipykernel_2374/2652284630.py:3: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   algo_df = pd.read_csv(algo_data, index_col = 'Date', parse_dates = True, infer_datetime_format = True)
#               Algo 1  Algo 2
# Date
# 2014-05-28  0.001745     NaN
# 2014-05-29  0.003978     NaN
# 2014-05-30  0.004464     NaN
# 2014-06-02  0.005692     NaN
# 2014-06-03  0.005292     NaN

# %%
# Count nulls
algo_df.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
algo_df.dropna(inplace = True)
algo_df.head()
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735
# 2014-06-11  0.004760 -0.003761

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P 500 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P 500 Closing Prices
sp500_data = Path("../Starter_Code/Resources/sp500_history.csv")
sp500_df = pd.read_csv(sp500_data, index_col = 'Date', parse_dates = True, infer_datetime_format = True)
sp500_df.sort_index(inplace = True)
sp500_df.head()
# Out:
# /var/folders/lt/6l09ks9x0bg715j61zl5fbb00000gn/T/ipykernel_2374/3050208982.py:3: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   sp500_df = pd.read_csv(sp500_data, index_col = 'Date', parse_dates = True, infer_datetime_format = True)
# /var/folders/lt/6l09ks9x0bg715j61zl5fbb00000gn/T/ipykernel_2374/3050208982.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   sp500_df = pd.read_csv(sp500_data, index_col = 'Date', parse_dates = True, infer_datetime_format = True)
#                Close
# Date
# 2012-10-01  $1444.49
# 2012-10-02  $1445.75
# 2012-10-03  $1450.99
# 2012-10-04  $1461.40
# 2012-10-05  $1460.93

# %%
# Check Data Types
sp500_df.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Fix Data Types
sp500_df['Close'] = pd.to_numeric(sp500_df['Close'].str.replace('$', ''), errors='coerce')
sp500_df.head()
# Out:
#               Close
# Date
# 2012-10-01  1444.49
# 2012-10-02  1445.75
# 2012-10-03  1450.99
# 2012-10-04  1461.40
# 2012-10-05  1460.93

# %%
# Calculate Daily Returns
daily_rtn_sp500 = sp500_df.pct_change()
daily_rtn_sp500.head()
# Out:
#                Close
# Date
# 2012-10-01       NaN
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322

# %%
# Drop nulls
daily_rtn_sp500.dropna(inplace = True)
daily_rtn_sp500.head()
# Out:
#                Close
# Date
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# 2012-10-08 -0.003457

# %%
# Rename `Close` Column to be specific to this portfolio.
daily_rtn_sp500.columns = ['SP500_Return']
daily_rtn_sp500.head()
# Out:
#             SP500_Return
# Date
# 2012-10-02      0.000872
# 2012-10-03      0.003624
# 2012-10-04      0.007174
# 2012-10-05     -0.000322
# 2012-10-08     -0.003457

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P 500 Returns into a single DataFrame with columns for each portfolio's returns.
combined_df = pd.concat([whale_df, algo_df, daily_rtn_sp500], axis = "columns", join = 'inner')
combined_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2  SP500_Return
# Date
# 2015-03-03 -0.000949     -0.004539
# 2015-03-04  0.002416     -0.004389
# 2015-03-05  0.004323      0.001196
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios
combined_df.plot(figsize = (10, 5))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios

combined_df_cumprod = (1 + combined_df).cumprod()

# Plot cumulative returns

combined_df_cumprod.plot(figsize = (10, 5))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk
ax = combined_df.plot.box()
ax.set_xticklabels(ax.get_xticklabels(), rotation = 45)
# Out:
# [Text(1, 0, 'SOROS FUND MANAGEMENT LLC'),
#  Text(2, 0, 'PAULSON & CO.INC. '),
#  Text(3, 0, 'TIGER GLOBAL MANAGEMENT LLC'),
#  Text(4, 0, 'BERKSHIRE HATHAWAY INC'),
#  Text(5, 0, 'Algo 1'),
#  Text(6, 0, 'Algo 2'),
#  Text(7, 0, 'SP500_Return')]

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios
combined_std = combined_df.std()
combined_std.sort_values(ascending = False, inplace = True)
combined_std
# Out:
# BERKSHIRE HATHAWAY INC         0.012919
# TIGER GLOBAL MANAGEMENT LLC    0.010894
# SP500_Return                   0.008554
# Algo 2                         0.008342
# SOROS FUND MANAGEMENT LLC      0.007895
# Algo 1                         0.007620
# PAULSON & CO.INC.              0.007023
# dtype: float64

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P 500

# %%
# Calculate  the daily standard deviation of S&P 500
daily_std_sp500 = combined_std[2]

# Determine which portfolios are riskier than the S&P 500
portfolios = combined_std[combined_std > daily_std_sp500]
portfolios
# Out:
# BERKSHIRE HATHAWAY INC         0.012919
# TIGER GLOBAL MANAGEMENT LLC    0.010894
# dtype: float64

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)

combined_std_annualized = combined_std * np.sqrt(252)
combined_std_annualized
# Out:
# BERKSHIRE HATHAWAY INC         0.205077
# TIGER GLOBAL MANAGEMENT LLC    0.172936
# SP500_Return                   0.135786
# Algo 2                         0.132430
# SOROS FUND MANAGEMENT LLC      0.125335
# Algo 1                         0.120967
# PAULSON & CO.INC.              0.111488
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for all portfolios using a 21-day window
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P 500
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta between it and the S&P 500

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window
# Plot the rolling standard deviation
combined_df.rolling(window = 21).std().plot(figsize = (10, 5))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation

correlation = combined_df.corr()

# Display de correlation matrix

sns.heatmap(correlation, vmin = -1, vmax = 1, annot = True)
# Out:
# <Axes: >

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 500

# %%
# Calculate covariance of a single portfolio

covariance_matrix = combined_df.cov()
covariance_SP500 = covariance_matrix.loc['SP500_Return']

# Calculate variance of S&P 500
var_sp500 = combined_df['SP500_Return'].var()

# Computing beta
beta = covariance_SP500 / var_sp500
beta.sort_values(ascending = False)

# Plot beta trend
# Out:
# BERKSHIRE HATHAWAY INC         1.134789
# SP500_Return                   1.000000
# Algo 2                         0.837535
# TIGER GLOBAL MANAGEMENT LLC    0.794653
# SOROS FUND MANAGEMENT LLC      0.773375
# PAULSON & CO.INC.              0.549886
# Algo 1                         0.248991
# Name: SP500_Return, dtype: float64

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half life for each portfolio, using standard deviation (`std`) as the metric of interest.

# %%
# Use `ewm` to calculate the rolling window
combined_df.ewm(halflife = 21).std().plot(figsize = (10, 5))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratios
sharpe_ratios = (combined_df.mean() * 252) / (combined_df.std() * np.sqrt(252))

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios.plot(kind = 'barh', figsize = (10, 5))
# Out:
# <Axes: >

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios.
#
# Write your answer here!

# %% [markdown]
# --Only Algo 1 outperms both S&P 500 and the whales portfolios

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others
# 5. Include correlation analysis to determine which stocks (if any) are correlated

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
# Reading data from 1st stock
aapl_data = Path("../Starter_Code/Resources/aapl_historical.csv")
aapl_df = pd.read_csv(aapl_data, index_col = 'Date', parse_dates = True)
aapl_df.sort_index(inplace = True)
aapl_df.head()
# Out:
#             Close
# Date
# 2015-03-02  32.27
# 2015-03-03  32.34
# 2015-03-04  32.14
# 2015-03-05  31.60
# 2015-03-06  31.65

# %%
# Reading data from 2nd stock
googl_data = Path("../Starter_Code/Resources/goog_historical.csv")
googl_df = pd.read_csv(googl_data, index_col = 'Date', parse_dates = True)
googl_df.sort_index(inplace = True)
googl_df.head()
# Out:
#             Close
# Date
# 2015-03-02  28.75
# 2015-03-03  28.94
# 2015-03-04  28.92
# 2015-03-05  29.07
# 2015-03-06  28.65

# %%
# Reading data from 3rd stock
cost_data = Path("../Starter_Code/Resources/cost_historical.csv")
cost_df = pd.read_csv(cost_data, index_col = 'Date', parse_dates = True)
cost_df.sort_index(inplace = True)
cost_df.head()
# Out:
#              Close
# Date
# 2015-03-02  147.94
# 2015-03-03  147.37
# 2015-03-04  147.17
# 2015-03-05  151.17
# 2015-03-06  149.54

# %%
# Combine all stocks in a single DataFrame
my_portfolio = pd.concat([aapl_df, googl_df, cost_df], axis = 'columns', join = 'inner')
my_portfolio.head()
# Out:
#             Close  Close   Close
# Date
# 2015-03-02  32.27  28.75  147.94
# 2015-03-03  32.34  28.94  147.37
# 2015-03-04  32.14  28.92  147.17
# 2015-03-05  31.60  29.07  151.17
# 2015-03-06  31.65  28.65  149.54

# %%
# Reset Date index

# %%
# Reorganize portfolio data by having a column per symbol
my_portfolio.columns = ['AAPL', 'GOOGL', 'COST']
my_portfolio.head()
# Out:
#              AAPL  GOOGL    COST
# Date
# 2015-03-02  32.27  28.75  147.94
# 2015-03-03  32.34  28.94  147.37
# 2015-03-04  32.14  28.92  147.17
# 2015-03-05  31.60  29.07  151.17
# 2015-03-06  31.65  28.65  149.54

# %%
# Calculate daily returns
my_portfolio_daily_rtn = my_portfolio.pct_change()

# Drop NAs
my_portfolio_daily_rtn.dropna(inplace = True)

# Display sample data
my_portfolio_daily_rtn.head()
# Out:
#                 AAPL     GOOGL      COST
# Date
# 2015-03-03  0.002169  0.006609 -0.003853
# 2015-03-04 -0.006184 -0.000691 -0.001357
# 2015-03-05 -0.016801  0.005187  0.027179
# 2015-03-06  0.001582 -0.014448 -0.010783
# 2015-03-09  0.004423  0.002094  0.007623

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [1/3, 1/3, 1/3]

# Calculate portfolio return
my_portfolio_rtn = my_portfolio_daily_rtn.dot(weights)

# Display sample data
my_portfolio_rtn.head()
# Out:
# Date
# 2015-03-03    0.001642
# 2015-03-04   -0.002744
# 2015-03-05    0.005188
# 2015-03-06   -0.007883
# 2015-03-09    0.004714
# dtype: float64

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame
all_df = pd.concat([combined_df, my_portfolio_rtn], axis = "columns", join = "inner")
all_df.rename(columns = {0: 'My_Portfolio'}, inplace = True)
all_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2  SP500_Return  My_Portfolio
# Date
# 2015-03-03 -0.000949     -0.004539      0.001642
# 2015-03-04  0.002416     -0.004389     -0.002744
# ...

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
#I use Google Finance function to filter the right date range, so no NaNs here

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized `std`
annualized_std = all_df.std() * np.sqrt(252)
annualized_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.125348
# PAULSON & CO.INC.              0.111527
# TIGER GLOBAL MANAGEMENT LLC    0.172989
# BERKSHIRE HATHAWAY INC         0.205079
# Algo 1                         0.121006
# Algo 2                         0.132413
# SP500_Return                   0.135787
# My_Portfolio                   0.177856
# dtype: float64

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation
annualized_std_rol21 = all_df.rolling(window = 21).std() * np.sqrt(252)

# Plot rolling standard deviation
annualized_std_rol21.plot(figsize = (10, 5))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate and plot the correlation

all_cor = all_df.corr()
sns.heatmap(all_cor, vmin = -1, vmax = 1, annot = True)
# Out:
# <Axes: >

# %% [markdown]
# ### Calculate and Plot Rolling 60-day Beta for Your Portfolio compared to the S&P 500

# %%
# Calculate and plot Beta
my_portfolio_cov = all_df['My_Portfolio'].rolling(window = 60).cov(all_df['SP500_Return']).dropna()
var_sp500_rol60 = combined_df['SP500_Return'].rolling(window = 60).var().dropna()
my_portfolio_beta = my_portfolio_cov / var_sp500_rol60
my_portfolio_beta.plot(figsize = (10, 5))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualized Sharpe Ratios
all_sr = (all_df.mean() * 252) / (all_df.std() * np.sqrt(252))

# %%
# Visualize the sharpe ratios as a bar plot
all_sr.plot(kind = 'barh', figsize = (10, 5))
# Out:
# <Axes: >

# %% [markdown]
# ### How does your portfolio do?
#
# Write your answer here!

# %%
## Calculate and Plot cumulative returns of all portfolios
all_df_cumulative_rtn = (1 + all_df).cumprod()
all_df_cumulative_rtn.plot(figsize = (10, 5))
# Out:
# <Axes: xlabel='Date'>

# %%
#According to the Sharpe Ratio and the cumulative return , my portfolio consisting AAPL, GOOGL and COST, is not as effecient as Algo 1.
